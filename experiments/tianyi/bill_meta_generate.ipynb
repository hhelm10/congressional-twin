# %%
import pickle

bill_meta = {
    '117-HR-1319': {
        'abstract': 'To provide for reconciliation pursuant to title II of S. Con. Res. 5',
        'summary': 'This bill provides additional relief to address the continued impact of COVID-19 (i.e., coronavirus disease 2019) on the economy, public health, state and local governments, individuals, and businesses.',
        'house_vote_date': '2021-02-27',
        'house_vote_id': '117-2021_h49',
        'senate_vote_date': '2021-03-06',
        'senate_vote_id': '117-2021_s110',
        'questions-1': [
            "Do you support the additional COVID-19 relief measures proposed in this bill?",
            "Which provisions of the bill do you believe will have the most significant impact?",
            "Are there any aspects of the bill you disagree with or would like to see modified?",
            "How do you think this bill will affect the economy in the short and long term?",
            "Does the bill provide adequate support for public health initiatives against COVID-19?",
            "In what ways will this bill assist state and local governments dealing with the pandemic?",
            "Do you feel the bill sufficiently addresses the needs of individuals and businesses impacted by COVID-19?",
            "What are your thoughts on the fiscal implications of the bill's proposed spending?",
            "How does this legislation compare to previous COVID-19 relief efforts?",
            "What feedback have you received from your constituents regarding this bill?"
        ],
        'questions-2': [
            "What is your overall stance on the proposed COVID-19 relief bill?",
            "Do you believe the funding allocated to public health initiatives is sufficient?",
            "How does the bill support state and local governments affected by the pandemic?",
            "In your opinion, does the bill adequately address the needs of individuals impacted by COVID-19?",
            "What provisions are included for businesses, and how effective do you think they will be?",
            "Are there specific measures in the bill you disagree with or would like to see modified?",
            "How will this bill impact the economy in both the short term and long term?",
            "Do you think the relief measures are appropriately targeted to those most in need?",
            "What is your perspective on the unemployment benefits outlined in the bill?",
            "Does the bill provide sufficient resources for vaccine distribution and public health efforts?",
            "Are you concerned about the bill's effect on the federal deficit and national debt?",
            "How does the legislation address the challenges faced by the education sector during the pandemic?",
            "Do you support the direct financial payments to individuals included in the bill?",
            "What assistance does the bill offer for housing and rental support?",
            "How are healthcare and frontline workers accounted for in this relief package?",
            "Does the bill include support for industries severely hit by the pandemic, such as hospitality and travel?",
            "What oversight mechanisms are in place to ensure responsible use of the relief funds?",
            "Does the bill do enough to address the disparities in how COVID-19 has affected different communities?",
            "How will this legislation enhance preparedness for future public health crises?",
            "Would you propose any amendments to improve the bill before it is passed?"
        ]
    },
    '117-HR-4346': {
        'abstract': 'Making appropriations for Legislative Branch for the fiscal year ending September 30, 2022, and for other purposes.',
        'summary': 'This bill includes provisions on two separate subjects: 1) the domestic production of semiconductors and incentives for science and technology research and development and 2) supplemental funding for U.S. marshals and other officers to protect the Supreme Court and its justices and staff from "threats". The bill began as a funding bill for the legislative branch. On June 22, 2022, the Senate replaced those provisions with the unrelated provisions related to the Supreme Court (titled the Supreme Court Security Funding Act of 2022). On July 27, 2022, additional unrelated provisions related to domestic semiconductor production (the CHIPS Act of 2022) and science and technology research and development (the Research and Development, Competition, and Innovation Act) were added.',
        'house_vote_date': '2021-07-28',
        'house_vote_id': '117-2021_h239',
        'senate_vote_date': '2022-06-22',
        'senate_vote_id': '117-2022_s271',
        'questions-1': [
            "Do you support the provisions aimed at boosting domestic semiconductor production? Why or why not?",
            "What is your stance on the incentives for science and technology research and development included in the bill?",
            "How do you feel about the supplemental funding for protecting the Supreme Court and its justices from threats?",
            "Do you believe it's appropriate to combine these diverse provisions into a single bill?",
            "How might the CHIPS Act impact the U.S. economy and global competitiveness in technology?",
            "Are you concerned about the process of adding unrelated provisions to the original funding bill?",
            "What are the potential benefits or drawbacks of this bill that stand out to you?",
            "How does this legislation align with your views on national security and technological independence?",
            "In your opinion, does the bill allocate funds effectively considering current budgetary priorities?",
            "Will you support this bill when it comes to a vote? What factors are influencing your decision?"
        ],
        'questions-2': [
            "What are your thoughts on the inclusion of semiconductor production incentives in the bill?",
            "Do you support the provisions related to the CHIPS Act of 2022 included in this bill?",
            "How do you feel about the supplemental funding for U.S. marshals to protect the Supreme Court and its justices?",
            "Do you believe that providing additional security funding for the Supreme Court is necessary at this time?",
            "What is your opinion on the Research and Development, Competition, and Innovation Act provisions included in the bill?",
            "How do you view the process by which the Senate replaced the original legislative branch funding provisions with unrelated topics?",
            "Do you think it is appropriate to include multiple unrelated provisions in a single bill?",
            "How might the incentives for science and technology R&D impact the U.S. economy?",
            "What benefits do you foresee from boosting domestic semiconductor production?",
            "Are there any concerns you have about the costs associated with the CHIPS Act provisions?",
            "How important is it for the U.S. to remain competitive in science and technology research?",
            "Do you agree with combining funding for Supreme Court security with semiconductor incentives in one bill?",
            "What impact do you think this bill will have on national security?",
            "How do you respond to critics who say that the bill combines unrelated issues?",
            "What measures are included in the bill to ensure accountability for the allocated funds?",
            "How do you plan to vote on this bill, and what are your main reasons?",
            "Do you have concerns about the transparency of the legislative process used for this bill?",
            "How will the provisions in this bill affect your constituents?",
            "What are the long-term implications of the science and technology provisions in the bill?",
            "Do you think the bill adequately addresses the threats faced by Supreme Court justices and staff?"
        ]
    },
    '118-HR-347': {
        'abstract': 'To require the Executive Office of the President to provide an inflation estimate with respect to Executive orders with a significant effect on the annual gross budget, and for other purposes.',
        'summary': 'This bill requires the Office of Management and Budget and the Council of Economic Advisers to provide an inflation estimate for each executive order that is projected to cause an annual gross budgetary or economic effect of at least $1 million.',
        'house_vote_date': '2023-03-01', 
        'house_vote_id': '118-2023_h131',
        'senate_vote_date': '',
        'senate_vote_id': '',
        'questions-1': [
            "Do you support the requirement for inflation estimates on executive orders with significant economic impact?",
            "How do you believe this bill will affect the transparency of executive actions?",
            "In your opinion, will providing inflation estimates aid in better policy-making decisions?",
            "Are there concerns about the accuracy of estimating inflation impacts for executive orders?",
            "How might this bill influence the relationship between the executive branch and Congress?",
            "Do you think the $1 million threshold is appropriate for requiring an inflation estimate?",
            "What effect do you anticipate this bill will have on the speed and efficiency of issuing executive orders?",
            "Are there potential downsides or unintended consequences of this bill that worry you?",
            "How will this requirement impact the workload and resources of the Office of Management and Budget and the Council of Economic Advisers?",
            "Do you believe this bill will effectively help mitigate inflationary pressures in the economy?"
        ],
        'questions-2': [
            "Do you support or oppose the bill requiring an inflation estimate for significant executive orders?",
            "What are your main reasons for supporting or opposing this legislation?",
            "How do you believe this bill will impact transparency within the executive branch?",
            "Do you think requiring inflation estimates will promote greater fiscal responsibility?",
            "Is the $1 million threshold appropriate for triggering the inflation estimate requirement?",
            "What benefits do you anticipate this bill will bring to economic policy-making?",
            "Are there any potential drawbacks or unintended consequences you foresee with this bill?",
            "How might this requirement affect the efficiency of issuing executive orders?",
            "Do you have concerns about the administrative burden on the Office of Management and Budget and the Council of Economic Advisers?",
            "In what ways could this bill influence the relationship between the executive and legislative branches?",
            "Do you believe this legislation will help mitigate inflationary pressures in the economy?",
            "How does this bill align with your views on government accountability and oversight?",
            "Could the requirement for inflation estimates delay urgent actions needed through executive orders?",
            "What feedback have you received from your constituents regarding this bill?",
            "Do you think the scope of the bill should be expanded or narrowed? If so, how?",
            "How confident are you in the ability of economic advisors to accurately estimate inflation impacts?",
            "Do you see this bill setting a precedent for future checks on executive actions?",
            "What impact do you think this bill will have on controlling government spending?",
            "Are there any amendments you would propose to improve the bill?",
            "How important is it for the public to understand the inflationary impact of executive orders?"
        ]
    },
    '118-HR-1435': {
        'abstract': 'To amend the Clean Air Act to prevent the elimination of the sale of internal combustion engines.',
        'summary': 'This bill modifies the waiver process under the Clean Air Act related to state emission control standards for new motor vehicles (or new motor vehicle engines).',
        'house_vote_date': '2023-09-14',
        'house_vote_id': '118-2023_h391',
        'senate_vote_date': '',
        'senate_vote_id': '',
        'questions-1': [
            "Do you support the bill that aims to prevent the elimination of the sale of internal combustion engines?",
            "How do you think this bill will impact efforts to reduce emissions and combat climate change?",
            "What is your stance on states' rights to set their own emission control standards under the Clean Air Act?",
            "Do you believe this bill balances environmental concerns with economic and industry interests effectively?",
            "How might this legislation affect the automotive industry and consumers who are moving towards electric vehicles?",
            "Are there alternative solutions you would propose to address vehicle emissions without limiting state authority?",
            "How does this bill align with the federal government's overall environmental and energy policies?",
            "What feedback have you received from your constituents regarding this proposed amendment to the Clean Air Act?",
            "Do you think limiting states' abilities to enforce stricter emission standards is appropriate or necessary?",
            "In your view, how will this bill influence the transition to cleaner energy and transportation technologies?"
        ],
        'questions-2': [
            "What is your overall opinion on the bill to amend the Clean Air Act to prevent the elimination of the sale of internal combustion engines?",
            "Do you believe that internal combustion engines should continue to be sold in the United States?",
            "How do you think this bill will impact efforts to reduce greenhouse gas emissions?",
            "What are your thoughts on the modification of the waiver process under the Clean Air Act proposed by this bill?",
            "Do you support state-level emission control standards that are stricter than federal standards?",
            "How might this bill affect the balance of power between federal and state governments regarding environmental regulations?",
            "What is your stance on the role of the federal government in setting nationwide emission standards?",
            "Do you think preventing states from eliminating internal combustion engine sales infringes on states' rights?",
            "How do you believe this bill will impact the automotive industry and its workers?",
            "What effect do you anticipate this bill will have on the advancement and adoption of electric vehicles?",
            "Do you think consumers should have the freedom to choose between internal combustion engines and electric vehicles?",
            "How does this bill align with the United States' commitments to international climate agreements?",
            "What are your concerns about air quality and public health in relation to this bill?",
            "In what ways might this bill influence innovation in green technology and alternative fuels?",
            "Do you believe there should be a timeline for transitioning away from internal combustion engines?",
            "What economic impacts do you foresee this bill having on industries dependent on fossil fuels?",
            "How do you address the concerns of constituents who support stricter emission standards to combat climate change?",
            "Do you believe modifying the waiver process under the Clean Air Act is justified?",
            "How do you intend to vote on this bill, and what factors are guiding your decision?",
            "Are there any amendments or changes you would propose to improve this bill?"
        ]
    },
#     '118-HR-2670': {
#         'abstract': 'To authorize appropriations for fiscal year 2024 for military activities of the Department of Defense and for military construction, and for defense activities of the Department of Energy, to prescribe military personnel strengths for such fiscal year, and for other purposes.',
#         'summary': 'This bill authorizes FY2024 appropriations and sets forth policies for Department of Defense (DOD) programs and activities, military construction, the national security programs of the Department of Energy (DOE), and the Maritime Administration, as well as the Department of State and the Central Intelligence Agency (CIA). It also authorizes appropriations for the Defense Nuclear Safety Board and the Naval Petroleum Reserves, and sets policy for several other agencies, including the Department of Homeland Security (DHS). The bill authorizes appropriations, but it does not provide budget authority, which is provided by appropriations legislation.',
#         'house_vote_date': '2023-07-14',
#         'house_vote_id': '',
#         'senate_vote_date': '2023-12-13',
#         'senate_vote_id': '',
#         'questions': [
#             "Do you support the overall level of funding authorized for the Department of Defense in this bill? Why or why not?",
#             "What are your views on the allocations for military construction projects outlined in the bill?",
#             "How does this bill address the personnel strengths and readiness of the military for fiscal year 2024?",
#             "Do you believe the funding for the Department of Energy's national security programs is appropriate? Why or why not?",
#             "Are there specific provisions in the bill related to the Central Intelligence Agency or Department of State that you agree or disagree with?",
#             "How does this legislation impact the operations of the Department of Homeland Security?",
#             "What is your stance on the appropriations authorized for the Defense Nuclear Safety Board and the Naval Petroleum Reserves?",
#             "Given that the bill authorizes appropriations but does not provide budget authority, how do you foresee it influencing the appropriations process?",
#             "In what ways does this bill address current national security challenges facing the United States?",
#             "Are there any amendments or changes you would like to see made to this bill before it is passed?"
#         ]
#     },
#     '118-HR-2872': {
#         'abstract': 'Making further continuing appropriations for the fiscal year ending September 30, 2024, and for other purposes.',
#         'summary': 'This act provides continuing FY2024 appropriations for federal agencies. The act also extends several expiring programs and authorities, including several public health programs.',
#         'house_vote_date': '2024-01-18',
#         'house_vote_id': '',
#         'senate_vote_date': '2024-01-18',
#         'senate_vote_id': '',
#         'questions': [
#             "Do you support the continuation of FY2024 appropriations for federal agencies as proposed in this bill?",
#             "What are your thoughts on extending the expiring public health programs included in the act?",
#             "Are there specific provisions in the bill that you particularly support or oppose?",
#             "How do you feel about using a continuing resolution versus passing a full appropriations bill?",
#             "Do you believe the funding levels provided are sufficient for federal agencies to operate effectively?",
#             "What impact do you think this bill will have on your constituents and the services they rely on?",
#             "Are there concerns about the potential impact of this bill on the federal budget and national debt?",
#             "How important is it to pass this bill to avoid a government shutdown?",
#             "Do you feel this bill addresses the most urgent needs facing the country right now?",
#             "Would you suggest any amendments to this bill? If so, what changes would you recommend?"
#         ]
#     },
    '118-HR-4639': {
        'abstract': 'To amend section 2702 of title 18, United States Code, to prevent law enforcement and intelligence agencies from obtaining subscriber or customer records in exchange for anything of value, to address communications and records in the possession of intermediary internet service providers, and for other purposes.',
        'summary': 'This bill would prohibit law enforcement from buying data from data brokers to circumvent the fourth amendment.',
        'house_vote_date': '2024-04-17',
        'house_vote_id': '118-2024_h136',
        'senate_vote_date': '',
        'senate_vote_id': '',
        'questions-1': [
            "Do you support this bill that prohibits law enforcement from purchasing data from data brokers without a warrant? Why or why not?",
            "How do you believe this legislation will impact law enforcement's ability to investigate crimes effectively?",
            "What are your thoughts on the balance between individual privacy rights and national security concerns in the context of this bill?",
            "Do you think purchasing data without a warrant circumvents Fourth Amendment protections against unreasonable searches and seizures?",
            "How might this bill affect the business practices of data brokers and intermediary internet service providers?",
            "Should there be exceptions in the bill for cases involving national security or terrorism? Please explain your stance.",
            "In what ways does this bill align or conflict with your views on digital privacy and government surveillance?",
            "What feedback have you received from your constituents regarding this proposed legislation?",
            "Do you foresee any unintended consequences that might arise if this bill becomes law?",
            "Are there any amendments or changes you would suggest to improve this bill before it is passed?"
        ],
        'questions-2': [
            "Do you support prohibiting law enforcement agencies from purchasing data from data brokers without a warrant?",
            "How do you feel about intelligence agencies obtaining subscriber records in exchange for something of value?",
            "What is your stance on the practice of law enforcement circumventing the Fourth Amendment by buying personal data?",
            "Should there be stricter regulations on data brokers selling customer information to government agencies?",
            "How might this bill impact the effectiveness of law enforcement and intelligence operations?",
            "Do you believe individuals have a right to privacy concerning data held by intermediary internet service providers?",
            "What are your views on addressing communications and records in the possession of ISPs as outlined in the bill?",
            "How should the balance be struck between national security interests and individual privacy rights?",
            "Are there circumstances where you think law enforcement should be allowed to purchase data without a warrant?",
            "What impact do you think this bill will have on data brokers and their business models?",
            "Do you agree with amending Section 2702 of Title 18 to prevent the exchange of customer records for value?",
            "How do you think this legislation will affect the relationship between private companies and government agencies?",
            "What measures do you support to ensure intelligence agencies operate within constitutional boundaries?",
            "Do you foresee any unintended consequences arising from the implementation of this bill?",
            "How important is it to protect citizens' digital privacy in today's technological landscape?",
            "What other policies would you advocate for to enhance privacy protections for consumer data?",
            "Do you think this bill adequately addresses the issues related to intermediary internet service providers?",
            "How does this proposed legislation align with existing laws on surveillance and data privacy?",
            "In your opinion, does purchasing data without judicial oversight constitute a violation of constitutional rights?",
            "Will this bill hinder the ability of agencies to prevent threats, or is it a necessary step to protect privacy?"
        ]
        
    },
    '118-HR-7888': {
        'abstract': 'To reform the Foreign Intelligence Surveillance Act of 1978.',
        'summary': 'This bill reauthorizes Title VII of the Foreign Intelligence Surveillance Act (FISA) for five years and makes changes to FISA, including certain restrictions on surveillance under Section 702. (Sec. 702 concerns electronic surveillance of non-U.S. persons believed to be outside the United States to obtain foreign intelligence information. Information about U.S. persons may incidentally be acquired by this type of surveillance and subsequently searched or "queried" under certain circumstances.)',
        'house_vote_date': '2024-04-12',
        'house_vote_id': '118-2024_h119',
        'senate_vote_date': '2024-04-19',
        'senate_vote_id': '118-2024_s150',
        'questions-1': [
            "Do you support the reauthorization of Title VII of the FISA, and why or why not?",
            "What are your views on the proposed restrictions on surveillance under Section 702?",
            "How do you balance national security concerns with the privacy rights of U.S. persons?",
            "Do you believe the current oversight mechanisms for FISA surveillance are adequate?",
            "What measures does the bill include to prevent the incidental collection of U.S. persons' information?",
            "How might this bill impact the effectiveness of foreign intelligence gathering?",
            "Are there any amendments you would like to see added to or removed from the bill?",
            "How does the bill address concerns about potential abuses of surveillance powers?",
            "In what ways does the bill enhance transparency and accountability in surveillance activities?",
            "What feedback have you received from your constituents regarding this bill, and how has it influenced your position?"
        ],
        'questions-2': [
            "Do you support the reauthorization of Title VII of the Foreign Intelligence Surveillance Act for another five years?",
            "What are your views on the current use of Section 702 for electronic surveillance of non-U.S. persons outside the United States?",
            "How do you feel about the incidental collection of information about U.S. persons during Section 702 surveillance?",
            "Do you believe the proposed restrictions on surveillance under Section 702 are sufficient to protect privacy rights?",
            "Should there be additional safeguards when querying incidentally collected information about U.S. persons?",
            "What changes would you recommend to FISA to better balance national security and civil liberties?",
            "Do you think a warrant should be required to search for U.S. persons' information collected under Section 702?",
            "How does this bill address concerns regarding potential privacy violations under FISA?",
            "Are you concerned about possible abuses of surveillance powers granted under FISA?",
            "What is your stance on the balance between national security needs and individual privacy rights in electronic surveillance?",
            "How effective do you believe Section 702 has been in obtaining valuable foreign intelligence?",
            "Do you support the specific changes this bill proposes to Section 702 surveillance procedures?",
            "How will the reforms in this bill impact the operations of intelligence agencies?",
            "What measures does the bill include to prevent unauthorized use of data on U.S. persons?",
            "Is the five-year reauthorization period appropriate, or should it be adjusted?",
            "How should Congress ensure compliance with constitutional protections in surveillance activities?",
            "What are the potential risks to national security if Title VII of FISA is not reauthorized?",
            "Does the bill adequately address the issue of transparency in surveillance practices?",
            "Do you believe current oversight mechanisms for FISA are sufficient?",
            "How might this bill affect the United States' relationships with foreign intelligence partners?"
        ]
    },
    '118-HR-8035': {
        'abstract': 'Making emergency supplemental appropriations to respond to the situation in Ukraine and for related expenses for the fiscal year ending September 30, 2024, and for other purposes.',
        'summary': 'This bill provides FY2024 supplemental appropriations for federal departments and agencies to respond to the conflict in Ukraine. The bill designates the funding as emergency spending, which is exempt from discretionary spending limits.',
        'house_vote_date': '2024-04-20', 
        'house_vote_id': '118-2024_h151',
        'senate_vote_date': '',
        'senate_vote_id': '',
        'questions-1': [
            "What are your overall thoughts on the proposed emergency supplemental appropriations for Ukraine?",
            "Do you support exempting this funding from discretionary spending limits, and why?",
            "How do you believe this funding will impact the situation in Ukraine?",
            "Are there specific areas within the bill that you agree or disagree with?",
            "How does this supplemental appropriation align with your views on U.S. foreign aid?",
            "Do you have concerns about the long-term fiscal implications of this emergency spending?",
            "In your opinion, should there be conditions attached to the aid provided to Ukraine?",
            "How do you think this bill affects U.S. national security interests?",
            "Would you propose any amendments to the bill to better address the situation in Ukraine?",
            "How do you respond to constituents who are worried about the cost of foreign assistance?"
        ],
        'questions-2':[
            "Do you support or oppose the emergency supplemental appropriations bill for Ukraine?",
            "What are your main reasons for supporting or opposing this bill?",
            "How do you feel about designating this funding as emergency spending exempt from discretionary spending limits?",
            "Do you believe the proposed funding levels are appropriate to respond to the conflict in Ukraine?",
            "How will this funding impact federal departments and agencies involved in the response?",
            "What specific areas should the funding focus on (e.g., military aid, humanitarian assistance, economic support)?",
            "Are there concerns about accountability and oversight of how the funds will be used?",
            "How does this bill align with your views on U.S. foreign policy toward Ukraine?",
            "Do you think the emergency funding is necessary at this point in time?",
            "What is your perspective on the potential impact of this spending on the federal budget and deficit?",
            "Do you see any issues with the exemption from discretionary spending limits?",
            "What other purposes are addressed in the bill besides responding to the situation in Ukraine?",
            "How does this bill coordinate with efforts from U.S. allies and international organizations?",
            "Are there alternative approaches you would suggest for assisting Ukraine?",
            "Does the bill adequately address the long-term strategy for U.S. involvement in Ukraine?",
            "How urgent do you believe the passage of this funding is?",
            "What feedback have you received from your constituents regarding this bill?",
            "How will you ensure effective and efficient use of the allocated funds?",
            "Do you have concerns about setting a precedent with this type of emergency spending designation?",
            "In what ways might this bill affect domestic priorities and spending?"
        ]

    },
    '118-HR-8038': {
        'abstract': 'To authorize the President to impose certain sanctions with respect to Russia and Iran, and for other purposes.',
        'summary': 'This bill establishes law on various foreign policy matters. For example, the bill requires the President to impose property-blocking sanctions on foreign persons (i.e., individuals and entities) associated with transnational criminal organizations that traffic fentanyl;authorizes the President to seize and transfer certain Russian sovereign assets to fund Ukrainian war compensation or reconstruction;prohibits entities in the United States from distributing, updating, or maintaining a website or application operated by ByteDance, Ltd., TikTok, or certain other entities;prohibits data brokers from providing personally identifiable sensitive data of U.S. persons to foreign adversary countries;imposes property-, docking-, and visa-blocking sanctions on foreign persons operating ports, ships, and refineries supporting Iranian petroleum exports;imposes property- and visa-blocking sanctions on foreign persons supporting Iranian missile programs and on certain Iranian leaders;imposes property-blocking sanctions on foreign states providing material support to Hamas or Palestinian Islamic Jihad; requires the United States to regulate exports of certain foreign-produced items related to Iran;extends the authority of the President to impose sanctions on foreign persons using human shields;imposes property- and visa-blocking sanctions on foreign persons involved in the trafficking of captagon;requires U.S. financial institutions to close certain accounts related to Iranian leaders and the Department of the Treasury to seek the closure of such accounts in foreign financial institutions; andprohibits U.S. financial institutions from opening or maintaining certain accounts with Chinese financial institutions that support Iranian petroleum exports.',
        'house_vote_date': '2024-04-20',
        'house_vote_id': '118-2024_h145',
        'senate_vote_date': '',
        'senate_vote_id': '',
        'questions-1': [
            "What are your overall thoughts on the proposed sanctions against Russia and Iran outlined in this bill?",
            "Do you support authorizing the President to seize and transfer Russian sovereign assets to fund Ukrainian war compensation or reconstruction? Why or why not?",
            "How do you view the measures to impose sanctions on individuals associated with transnational criminal organizations trafficking fentanyl?",
            "What is your stance on prohibiting U.S. entities from distributing or maintaining applications operated by ByteDance, Ltd., TikTok, or similar entities?",
            "Do you agree with prohibiting data brokers from providing sensitive personal data of U.S. persons to foreign adversary countries?",
            "How effective do you believe sanctions on foreign persons operating ports, ships, and refineries supporting Iranian petroleum exports will be?",
            "What is your opinion on imposing sanctions on foreign persons supporting Iranian missile programs and certain Iranian leaders?",
            "Do you think extending the President's authority to impose sanctions on those using human shields is necessary?",
            "How do you feel about requiring U.S. financial institutions to close accounts related to Iranian leaders and seeking the closure of such accounts in foreign institutions?",
            "What are your thoughts on prohibiting U.S. financial institutions from engaging with Chinese financial institutions that support Iranian petroleum exports?"
        ],
        'questions-2': [
            "What are your thoughts on imposing property-blocking sanctions on foreign persons associated with transnational criminal organizations that traffic fentanyl?",
            "Do you support authorizing the President to seize and transfer Russian sovereign assets to fund Ukrainian war compensation or reconstruction? Why or why not?",
            "How do you feel about prohibiting entities in the United States from distributing, updating, or maintaining websites or applications operated by ByteDance, Ltd., TikTok, or certain other entities?",
            "What is your position on prohibiting data brokers from providing personally identifiable sensitive data of U.S. persons to foreign adversary countries?",
            "Do you agree with imposing property-, docking-, and visa-blocking sanctions on foreign persons operating ports, ships, and refineries supporting Iranian petroleum exports?",
            "What are your views on imposing property- and visa-blocking sanctions on foreign persons supporting Iranian missile programs and on certain Iranian leaders?",
            "How do you perceive the impact of imposing property-blocking sanctions on foreign states providing material support to Hamas or Palestinian Islamic Jihad?",
            "Do you support regulating exports of certain foreign-produced items related to Iran? Why or why not?",
            "What is your stance on extending the authority of the President to impose sanctions on foreign persons using human shields?",
            "How effective do you think imposing property- and visa-blocking sanctions on foreign persons involved in the trafficking of captagon will be?",
            "Should U.S. financial institutions be required to close certain accounts related to Iranian leaders, and should the Treasury seek the closure of such accounts in foreign financial institutions?",
            "Do you agree with prohibiting U.S. financial institutions from opening or maintaining certain accounts with Chinese financial institutions that support Iranian petroleum exports?",
            "What is your opinion on the overall effectiveness of the proposed sanctions in achieving U.S. foreign policy goals?",
            "How might these sanctions impact diplomatic relations with Russia, Iran, and other affected countries?",
            "Do you have concerns about the potential economic impact of these sanctions on global markets?",
            "How do you think the prohibition on TikTok and ByteDance operations in the U.S. affects freedom of expression and access to information?",
            "What measures should be taken to protect U.S. citizens' data from being accessed by foreign adversaries?",
            "Do you believe that the sanctions related to Iran's missile programs will deter their development and proliferation?",
            "How do you assess the ethical implications of seizing foreign assets to fund another country's war compensation or reconstruction?",
            "Are there alternative strategies you would propose to address the issues targeted by this bill?"
        ]
    },
    '118-HR-6090': {
        'abstract': 'To provide for the consideration of a definition of antisemitism set forth by the International Holocaust Remembrance Alliance for the enforcement of Federal antidiscrimination laws concerning education programs or activities, and for other purposes.',
        'summary:': "This bill provides statutory authority for the requirement that the Department of Education’s Office for Civil Rights take into consideration the International Holocaust Remembrance Alliance's (IHRA's) working definition of antisemitism when reviewing or investigating complaints of discrimination based on race, color, or national origin in programs or activities that receive federal financial assistance. According to the IHRA's working definition, antisemitism is a certain perception of Jews, which may be expressed as hatred toward Jews.",
        'house_vote_date': '2024-05-01',
        'house_vote_id': '118-2024_h172',
        'senate_vote_date': '',
        'senate_vote_id': '',
        'questions-1': [
            "Do you support the adoption of the IHRA's working definition of antisemitism in federal antidiscrimination law enforcement? Why or why not?",
            "How do you believe implementing the IHRA definition will impact the enforcement of civil rights in educational programs?",
            "Are you concerned that adopting this definition might infringe upon freedom of speech or academic freedom?",
            "Do you think the IHRA definition could suppress legitimate criticism of the policies of the State of Israel?",
            "How does this bill align with existing anti-discrimination laws and policies?",
            "In your opinion, are current measures insufficient in addressing antisemitism? If so, how does this bill improve them?",
            "What are the potential benefits or drawbacks of codifying the IHRA's definition into law?",
            "How might this bill affect the expression rights of minority groups within educational institutions?",
            "Have you consulted with Jewish organizations or other stakeholders regarding this bill? What feedback have you received?",
            "Do you believe this legislation effectively addresses antisemitism on college campuses and in other educational settings?",
        ],
        'questions-2': [
            "What are your overall thoughts on adopting the IHRA's definition of antisemitism for enforcing antidiscrimination laws in education?",
            "Do you believe that incorporating this definition will strengthen protections against antisemitism in educational institutions?",
            "How might this bill impact the Department of Education's Office for Civil Rights in handling discrimination complaints?",
            "Are there concerns that the IHRA's definition could infringe on free speech or academic freedom?",
            "How do you think this legislation will affect federally funded education programs and activities?",
            "What is your perspective on the current state of antisemitism in educational settings today?",
            "Do you foresee any challenges in implementing the IHRA's definition within existing legal frameworks?",
            "How might this bill influence the review of complaints based on race, color, or national origin?",
            "Can you discuss the potential benefits or drawbacks of providing statutory authority for this specific definition?",
            "What implications does this bill have for educational institutions receiving federal financial assistance?",
            "How does adopting this definition align with existing federal antidiscrimination laws?",
            "Do you think additional measures are needed to combat antisemitism beyond what this bill proposes?",
            "How might this legislation affect interactions among diverse student groups on campuses?",
            "Are there alternative definitions of antisemitism that you believe should be considered?",
            "What feedback have you received from constituents regarding this proposed bill?",
            "Does this bill address incidents of antisemitism that may not be covered under current definitions?",
            "Do you feel the bill balances the need to combat antisemitism with the protection of free expression?",
            "What role should educational programs play in preventing antisemitism in light of this legislation?",
            "How important is it for federal agencies to have a standardized definition of antisemitism?",
            "Will implementing this bill require additional resources or training for the Office for Civil Rights?"
        ]
    },
    '118-HR-3746': {
        'abstract': 'To provide for a responsible increase to the debt ceiling.',
        'summary': "This bill would enact a compromise reached by House Republicans and President Biden to avert an impending fiscal crisis related to the statutory debt limit. In exchange for the continued solvency of the federal government, sought by Democrats, Republicans secured in the bill across-the-board cuts to federal spending, ending Biden's suspension of student loan repayments, adding new work requirements for SNAP and TANF, reinstituting the statutory debt limit after the 2024 elections, and more.",
        'house_vote_date': '2023-05-31',
        'senate_vote_date': '2023-06-01',
        'house_vote_id': '118-2023_h243',
        'senate_vote_id': '118-2023_s146',
        'questions-1': [
            "What is your overall position on the proposed increase to the debt ceiling in this bill?",
            "Do you support the across-the-board cuts to federal spending included in the bill? Why or why not?",
            "How do you feel about ending the suspension of student loan repayments?",
            "What is your opinion on adding new work requirements for SNAP and TANF recipients?",
            "Are you concerned about reinstating the statutory debt limit after the 2024 elections?",
            "Do you believe this compromise effectively averts the impending fiscal crisis?",
            "How do you think the spending cuts will impact federal programs and services?",
            "In your view, does the bill strike the right balance between fiscal responsibility and social support?",
            "What feedback have you received from your constituents regarding this bill?",
            "Are there any provisions in the bill you would like to see modified or removed?"
        ],
        'questions-2': [
            "Do you support the proposed increase in the debt ceiling to avert the fiscal crisis?",
            "What are your thoughts on the across-the-board cuts to federal spending included in the bill?",
            "How do you feel about ending the suspension of student loan repayments?",
            "Do you agree with adding new work requirements for SNAP and TANF beneficiaries?",
            "What is your opinion on reinstituting the statutory debt limit after the 2024 elections?",
            "Do you believe this bill represents a fair compromise between Democrats and Republicans?",
            "How will the proposed spending cuts affect essential federal programs and services?",
            "What impact do you think this bill will have on the overall economy?",
            "Are there specific areas of federal spending you believe should be exempt from cuts?",
            "How might ending student loan repayment suspensions affect borrowers and the economy?",
            "Do you think the new work requirements for SNAP and TANF will help or hinder recipients?",
            "How crucial is it to maintain the solvency of the federal government at this time?",
            "Are you concerned about potential negative consequences when the debt limit is reinstated after 2024?",
            "Which provisions in the bill do you most strongly support or oppose?",
            "How does this legislation align with the interests and needs of your constituents?",
            "Would you suggest any alternatives to the across-the-board spending cuts proposed?",
            "Do you believe this compromise sets a positive precedent for future bipartisan agreements?",
            "Can you explain how you plan to vote on this bill and the reasons behind your decision?",
            "What feedback have you received from your constituents regarding this bill?",
            "In your view, how will this bill affect the country's long-term fiscal health?"
        ]
    },
    '118-HR-8282': {
        'abstract': 'To impose sanctions with respect to the International Criminal Court engaged in any effort to investigate, arrest, detain, or prosecute any protected person of the United States and its allies.',
        'summary': '',
        'house_vote_date': '2024-06-04', 
        'house_vote_id': '118-2024_h242',
        'senate_vote_date': '',
        'senate_vote_id': '',
        'questions-1': [
            "Do you support or oppose the bill to impose sanctions on the International Criminal Court (ICC), and why?",
            "How do you believe this bill will affect the United States' relationship with international legal institutions like the ICC?",
            "What impact do you think this bill will have on accountability for international crimes such as war crimes and crimes against humanity?",
            "In your opinion, should U.S. and allied personnel be immune from prosecution by the ICC?",
            "How does this bill align with international law and the United States' obligations under international treaties?",
            "What are the potential repercussions of this bill on the United States' global standing and diplomatic relations?",
            "Do you have concerns about possible retaliatory actions from other nations or international bodies if this bill passes?",
            "How might this legislation affect the United States' ability to promote human rights and the rule of law internationally?",
            "What are the main benefits you see in imposing sanctions on the ICC through this bill?",
            "How do you balance national sovereignty with the need for international justice in the context of this legislation?"
        ],
        'questions-2': [
            "What are your overall thoughts on the bill proposing sanctions against the International Criminal Court (ICC)?",
            "Do you believe imposing sanctions on the ICC aligns with U.S. interests and values?",
            "How do you view the ICC's role in prosecuting international crimes such as genocide, war crimes, and crimes against humanity?",
            "Should U.S. personnel and allies be exempt from ICC investigations and prosecutions?",
            "What impact might this bill have on the U.S.'s relationship with allies who are members of the ICC?",
            "Do you think imposing sanctions on the ICC undermines international law and accountability?",
            "How might this bill affect the U.S.'s global standing on human rights issues?",
            "Are there concerns that this bill could set a precedent for other countries to evade international justice?",
            "What are the potential diplomatic repercussions of sanctioning the ICC?",
            "Do you believe that U.S. courts are sufficient to hold U.S. personnel accountable for international crimes?",
            "How does this bill align with previous U.S. policies toward the ICC?",
            "What measures does the bill propose to protect U.S. citizens and allies from ICC actions?",
            "Could this bill hinder cooperation with international partners on global justice initiatives?",
            "What are the legal justifications for imposing sanctions on an international judicial body like the ICC?",
            "How might this bill impact victims seeking justice through the ICC?",
            "Do you see any risks of retaliation from other nations if the U.S. sanctions the ICC?",
            "How does this bill balance national sovereignty with international obligations?",
            "What alternatives to sanctions could the U.S. pursue to address concerns with the ICC?",
            "Are there any provisions in the bill to address potential abuses by U.S. personnel abroad?",
            "How will this bill affect the U.S.'s commitment to upholding international norms and laws?"
        ]
    },
    '118-HR-8772': {
        'abstract': 'Making appropriations for the Legislative Branch for the fiscal year ending September 30, 2025, and for other purposes.',
        'summary': 'This bill provides FY2025 appropriations for the legislative branch.',
        'house_vote_date': '2024-07-11',
        'house_vote_id': '118-2024_h352',
        'senate_vote_date': '',
        'senate_vote_id': '',
        'questions-1': [
            "Do you support the proposed FY2025 appropriations for the legislative branch? Why or why not?",
            "What are the key areas where you believe the legislative branch needs increased funding?",
            "Are there any aspects of the legislative branch budget where you think spending should be reduced?",
            "How does this appropriations bill address transparency and accountability in legislative spending?",
            "Do you feel the proposed budget adequately supports staff and resources necessary for Congress to function effectively?",
            "In what ways does this bill impact funding for congressional offices and committees?",
            "What is your perspective on the allocation of funds between the House and the Senate in this bill?",
            "Does the bill introduce any significant changes compared to previous years' appropriations? If so, what are they?",
            "How will this appropriations bill affect Congress's ability to serve constituents?",
            "Are there any amendments or provisions in the bill that you particularly support or oppose?"
        ],
        'questions-2': [
            "What are your overall thoughts on the proposed FY2025 appropriations for the legislative branch?",
            "Do you believe the funding levels outlined in the bill are sufficient for the legislative branch to operate effectively?",
            "Are there specific areas within the legislative branch that you think should receive more or less funding?",
            "How does the bill address the needs of congressional staff and their compensation?",
            "What is your stance on the allocations for Capitol security in this appropriations bill?",
            "Does the bill provide adequate funding for technological upgrades and cybersecurity measures?",
            "How will the proposed appropriations impact the operations of the Congressional Budget Office?",
            "Do you support the funding allocated to the Library of Congress and its programs?",
            "What are your views on the resources provided for the Government Accountability Office in this bill?",
            "Are there any new initiatives or programs funded by this bill that you find particularly important?",
            "How does this bill balance fiscal responsibility with the needs of the legislative branch?",
            "Do you have any concerns about potential waste or inefficiencies in the proposed appropriations?",
            "What is your opinion on the transparency and accountability measures included in the bill?",
            "How might the appropriations affect constituent services provided by congressional offices?",
            "Are there provisions in the bill that address diversity, equity, and inclusion within the legislative workforce?",
            "Does the bill adequately fund oversight functions critical to government accountability?",
            "What impact will this bill have on the legislative branch's ability to respond to emerging challenges?",
            "Do you think the appropriations for committees and subcommittees are appropriately allocated?",
            "How does the bill support or hinder efforts to modernize legislative processes?",
            "Will you be voting for or against this bill, and what are your main reasons for your decision?"
        ]
    },
    '118-HR-5717': {
        'abstract': 'To provide that sanctuary jurisdictions that provide benefits to aliens who are present in the United States without lawful status under the immigration laws are ineligible for Federal funds intended to benefit such aliens.',
        'summary': 'This bill makes a state or political subdivision of a state ineligible for any federal funds the jurisdiction intends to use to benefit non-U.S. nationals (i.e., aliens under federal law) who are unlawfully present if the jurisdiction withholds information about citizenship or immigration status or does not cooperate with immigration detainers.',
        'house_vote_date':'2024-09-20',
        'house_vote_id': '118-2024_h437',
        'senate_vote_date': '',
        'senate_vote_id': '',
        'questions-1': [
            "Do you support or oppose this bill that would make sanctuary jurisdictions ineligible for federal funds intended to benefit unauthorized immigrants?",
            "What are your reasons for supporting or opposing the withholding of federal funds from sanctuary jurisdictions?",
            "How do you believe this bill will impact the relationship between federal and local governments?",
            "In your view, what are the potential social and economic effects of this bill on communities with large immigrant populations?",
            "Do you think withholding federal funds is an effective strategy to ensure compliance with federal immigration laws?",
            "How does this bill align with your broader stance on immigration reform and enforcement?",
            "What are your thoughts on the role of sanctuary jurisdictions in protecting vulnerable immigrant communities?",
            "Could this bill have unintended consequences on public safety or community trust in law enforcement? If so, how?",
            "How might this legislation affect the rights and well-being of unauthorized immigrants residing in sanctuary jurisdictions?",
            "What alternatives to this bill would you propose to address issues related to unauthorized immigration and federal funding?"
        ],
        'questions-2': [
            "What is your overall stance on this bill regarding federal funding for sanctuary jurisdictions?",
            "Do you believe that withholding federal funds is an effective way to enforce immigration laws?",
            "How do you think this bill will impact the relationship between federal and local governments?",
            "What are your views on sanctuary jurisdictions providing benefits to undocumented immigrants?",
            "Do you support requiring local authorities to share information about individuals' immigration status with federal agencies?",
            "How might this bill affect public safety in communities with large immigrant populations?",
            "Do you think penalizing jurisdictions that don't comply with immigration detainers is justified?",
            "What are the potential economic implications of this bill for states and local governments?",
            "How does this legislation align with your views on states' rights and federalism?",
            "What impact do you foresee this bill having on undocumented immigrants residing in sanctuary cities?",
            "Are there any constitutional concerns you have regarding the enforcement of this bill?",
            "How might this bill affect the trust between immigrant communities and law enforcement?",
            "Do you believe that denying federal funds could strain public services like healthcare and education in affected areas?",
            "What is your perspective on the moral responsibilities of states toward undocumented immigrants?",
            "How do you respond to concerns about possible increases in racial profiling due to this bill?",
            "In your opinion, does this bill effectively address the root causes of illegal immigration?",
            "What alternatives would you propose to improve immigration enforcement without penalizing local jurisdictions?",
            "How do you think this bill will influence the national dialogue on immigration reform?",
            "Do you anticipate any unintended consequences if this bill is enacted?",
            "Will you support or oppose this bill when it comes to a vote, and what are your reasons?"
        ]
    },
#     '118-HR-9747': {
#         'abstract': 'Making continuing appropriations and extensions for fiscal year 2025, and for other purposes.',
#         'summary': 'This act provides continuing FY2025 appropriations for federal agencies, provides additional funding for the U.S. Secret Service, and extends various expiring programs and authorities.',
#         'house_vote_date': '2024-09-25', 
#         'house_vote_id': '',
#         'senate_vote_date': '2024-09-25',
#         'senate_vote_id': '',
#         'questions': [
#             "Do you support the passage of this continuing appropriations bill for FY2025? Why or why not?",
#             "What are your thoughts on the additional funding allocated to the U.S. Secret Service in this bill?",
#             "How do you feel about extending various expiring programs and authorities through this legislation?",
#             "Are there any specific provisions in the bill that you particularly support or oppose?",
#             "Do you believe this bill adequately addresses the funding needs of federal agencies for FY2025?",
#             "What are your views on using continuing resolutions instead of passing new budget appropriations?",
#             "How might this bill impact fiscal responsibility and the federal budget deficit?",
#             "Do you have any concerns about the potential for increased government spending due to this bill?",
#             "In your opinion, does this bill effectively address any urgent national priorities?",
#             "Will you be voting in favor of this bill, and what factors are influencing your decision?"
#         ]
#     },
}


pickle.dump(bill_meta, open('bill_meta.p', 'wb'))

# %% [markdown]
# Here is an abstract and summary of a bill to be voted on:
# Please generate 20 questions related to the bill that you would ask a member of Congress to understand their opinion on the bill. The 20 questions should span all topics addressed in the bill. Output the questions as a Python list of strings in a code block.
